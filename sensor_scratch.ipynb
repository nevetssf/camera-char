# %% [markdown]
# # Camera Sensor Noise Analysis

# %% [markdown]
# I want to analyze the noise in the detector at different exposure times and different ISO settings, to see how how it varies.
#
# Questions:
#   - Readout noise vs. leakage noise
#   - Effect of Bayer filter
#   - Increase in noise with ISO setting
#   - Comparison of noise profiles between cameras
#
# I'm assuming the detector sensitivity is the same for each camera at a given ISO, per unit area. One day I might make a stable voltage source and use an LED to create a calibrated light source

# %%
import os

import exiftool
import rawpy
import numpy as np
import plotly.express as px
import pandas as pd
import skimage

# %%
suffix = 'DNG'
path = "Pixii"
fn_list = sorted([i for i in os.listdir(path) if i.upper().endswith(suffix)])
fn_list = [os.path.join(path, i) for i in fn_list]

# %%
fn_list
# Out:
# ['Pixii/P0000478.DNG',
#  'Pixii/P0000479.DNG',
#  'Pixii/P0000480.DNG',
#  'Pixii/P0000481.DNG',
#  'Pixii/P0000482.DNG',
#  'Pixii/P0000483.DNG',
#  'Pixii/P0000484.DNG',
#  'Pixii/P0000485.DNG',
#  'Pixii/P0000486.DNG',
#  'Pixii/P0000487.DNG',
#  'Pixii/P0000488.DNG',
#  'Pixii/P0000489.DNG',
#  'Pixii/P0000490.DNG',
#  'Pixii/P0000491.DNG',
#  'Pixii/P0000492.DNG',
#  'Pixii/P0000493.DNG',
#  'Pixii/P0000494.DNG',
#  'Pixii/P0000495.DNG',
#  'Pixii/P0000496.DNG',
#  'Pixii/P0000497.DNG',
#  'Pixii/P0000498.DNG',
#  'Pixii/P0000499.DNG',
#  'Pixii/P0000500.DNG',
#  'Pixii/P0000501.DNG',
#  'Pixii/P0000502.DNG',
#  'Pixii/P0000503.DNG',
#  'Pixii/P0000504.DNG',
#  'Pixii/P0000505.DNG',
#  'Pixii/P0000506.DNG',
#  'Pixii/P0000507.DNG',
#  'Pixii/P0000508.DNG',
#  'Pixii/P0000509.DNG',
#  'Pixii/P0000510.DNG',
#  'Pixii/P0000511.DNG',
#  'Pixii/P0000512.DNG',
#  'Pixii/P0000513.DNG',
#  'Pixii/P0000514.DNG',
#  'Pixii/P0000515.DNG',
#  'Pixii/P0000516.DNG',
#  'Pixii/P0000517.DNG',
#  'Pixii/P0000518.DNG',
#  'Pixii/P0000519.DNG',
#  'Pixii/P0000520.DNG',
#  'Pixii/P0000521.DNG',
#  'Pixii/P0000522.DNG',
#  'Pixii/P0000523.DNG',
#  'Pixii/P0000524.DNG',
#  'Pixii/P0000525.DNG',
#  'Pixii/P0000526.DNG',
#  'Pixii/P0000527.DNG',
#  'Pixii/P0000528.DNG',
#  'Pixii/P0000529.DNG',
#  'Pixii/P0000530.DNG',
#  'Pixii/P0000531.DNG',
#  'Pixii/P0000532.DNG',
#  'Pixii/P0000533.DNG',
#  'Pixii/P0000534.DNG',
#  'Pixii/P0000535.DNG',
#  'Pixii/P0000536.DNG',
#  'Pixii/P0000537.DNG',
#  'Pixii/P0000538.DNG',
#  'Pixii/P0000539.DNG',
#  'Pixii/P0000540.DNG',
#  'Pixii/P0000541.DNG']

# %%
with exiftool.ExifToolHelper() as et:
    metadata = et.get_metadata(fn_list[0:10])

# %%
len(metadata)
# Out:
# 10

# %%
metadata[0]
# Out:
# {'SourceFile': 'Pixii/P0000478.DNG',
#  'ExifTool:ExifToolVersion': 12.4,
#  'ExifTool:Warning': '[minor] Unrecognized MakerNotes',
#  'File:FileName': 'P0000478.DNG',
#  'File:Directory': 'Pixii',
#  'File:FileSize': 39644097,
#  'File:FileModifyDate': '2023:08:03 11:25:27-06:00',
#  'File:FileAccessDate': '2023:08:03 17:53:33-06:00',
#  'File:FileInodeChangeDate': '2023:08:03 17:51:43-06:00',
#  'File:FilePermissions': 100755,
#  'File:FileType': 'DNG',
#  'File:FileTypeExtension': 'DNG',
#  'File:MIMEType': 'image/x-adobe-dng',
#  'File:ExifByteOrder': 'II',
#  'EXIF:Make': 'PIXII SAS',
#  'EXIF:Model': 'Pixii Camera (A2572)',
#  'EXIF:PreviewImageStart': 2536,
#  'EXIF:Orientation': 1,
#  'EXIF:PreviewImageLength': 27161,
#  'EXIF:Software': '1.3-34c3b09',
#  'EXIF:ModifyDate': '2023:07:03 17:25:27',
#  'EXIF:SubfileType': 0,
#  'EXIF:ImageWidth': 6288,
#  'EXIF:ImageHeight': 4200,
#  'EXIF:BitsPerSample': 12,
#  'EXIF:Compression': 1,
#  'EXIF:PhotometricInterpretation': 32803,
#  'EXIF:StripOffsets': 29697,
#  'EXIF:SamplesPerPixel': 1,
#  'EXIF:RowsPerStrip': 4200,
#  'EXIF:StripByteCounts': 39614400,
#  'EXIF:PlanarConfiguration': 1,
#  'EXIF:ResolutionUnit': 2,
#  'EXIF:CFARepeatPatternDim': '2 2',
#  'EXIF:CFAPattern2': '1 2 0 1',
#  'EXIF:CFALayout': 1,
#  'EXIF:BlackLevel': 125,
#  'EXIF:WhiteLevel': 4095,
#  'EXIF:BayerGreenSplit': 50,
#  'EXIF:AntiAliasStrength': 0,
#  'EXIF:BestQualityScale': 1,
#  'EXIF:ActiveArea': '32 24 4200 6276',
#  'EXIF:ExposureTime': 1,
#  'EXIF:ExposureProgram': 1,
#  'EXIF:ISO': 160,
#  'EXIF:ExifVersion': '0221',
#  'EXIF:DateTimeOriginal': '2023:08:03 17:25:26',
#  'EXIF:OffsetTimeOriginal': '-07:00',
#  'EXIF:ExposureCompensation': 0,
#  'EXIF:MeteringMode': 2,
#  'EXIF:Flash': 0,
#  'EXIF:FocalLength': 28,
#  'EXIF:ExposureMode': 1,
#  'EXIF:WhiteBalance': 0,
#  'EXIF:LightSource': 0,
#  'EXIF:TIFF-EPStandardID': '1 0 0 0',
#  'EXIF:DNGVersion': '1 3 0 0',
#  'EXIF:DNGBackwardVersion': '1 1 0 0',
#  'EXIF:UniqueCameraModel': 'Pixii Camera (A2572)',
#  'EXIF:LocalizedCameraModel': 'Pixii Camera (A2572)',
#  'EXIF:ColorMatrix1': '1.7227 -0.8744 0.2001 -0.2928 1.1483 0.2763 -0.0355 0.0974 0.6195',
#  'EXIF:AnalogBalance': '1 1 1',
#  'EXIF:AsShotNeutral': '0.3961864412 1 0.3740000129',
#  'EXIF:BaselineExposure': 0,
#  'EXIF:BaselineSharpness': 1,
#  'EXIF:LinearResponseLimit': 1,
#  'EXIF:CalibrationIlluminant1': 20,
#  'EXIF:AsShotProfileName': 'Default',
#  'EXIF:ForwardMatrix1': '0.623 0.2548 0.0864 0.1453 0.8935 -0.0388 0.0441 -0.324 1.1051',
#  'EXIF:PreviewImage': '(Binary data 27161 bytes, use -b option to extract)',
#  'Composite:CFAPattern': '2 2 1 2 0 1',
#  'Composite:ImageSize': '6288 4200',
#  'Composite:Megapixels': 26.4096,
#  'Composite:ShutterSpeed': 1,
#  'Composite:SubSecDateTimeOriginal': '2023:08:03 17:25:26-07:00',
#  'Composite:FocalLength35efl': 28}

# %%
metadata[0].get('EXIF:UniqueCameraModel')
# Out:
# 'Pixii Camera (A2572)'

# %%
metadata[0].get('EXIF:BlackLevel')
# Out:
# 125

# %%
metadata[0].get('EXIF:ISO')
# Out:
# 160

# %%
metadata[0].get('SourceFile')
# Out:
# 'Pixii/P0000478.DNG'

# %%
metadata[0].get('EXIF:ExposureTime')
# Out:
# 1

# %%
fn_list[0]
# Out:
# 'Pixii/P0000478.DNG'

# %%
raw = rawpy.imread(fn_list[0])

# %%
raw.white_level
# Out:
# 4095

# %%
raw.raw_type
# Out:
# <RawType.Flat: 0>

# %%
raw.black_level_per_channel
# Out:
# [125, 125, 125, 125]

# %%
import imageio

# %% [markdown]
# The Leica Q has neutral grey strip at row 6011, so only keep columns 0 through 6010 inclusiv

# %%
raw.raw_image
# Out:
# array([[2128,    0,  360, ...,    0,    0,    0],
#        [   2,  125,  125, ...,    0,    0,    0],
#        [   3,  126,  126, ...,    0,    0,    0],
#        ...,
#        [ 102,  127,  126, ...,    0,    0,    0],
#        [ 103,  127,  126, ...,    0,    0,    0],
#        [ 104,  127,  125, ...,    0,    0,    0]], dtype=uint16)

# %%
raw.raw_image.shape
# Out:
# (4200, 6288)

# %%
rawpy.imread(fn_list[5]).raw_image
# Out:
# array([[2128,    0,  360, ...,    0,    0,    0],
#        [   2,  125,  125, ...,    0,    0,    0],
#        [   3,  126,  125, ...,    0,    0,    0],
#        ...,
#        [ 102,  126,  126, ...,    0,    0,    0],
#        [ 103,  126,  126, ...,    0,    0,    0],
#        [ 104,  125,  126, ...,    0,    0,    0]], dtype=uint16)

# %%
actual_image = raw.raw_image[:, 0:6030]
actual_image.shape
# Out:
# (4200, 6030)

# %%
raw.raw_image.shape
# Out:
# (4014, 6016)

# %%
imageio.imsave('test.tiff', raw.raw_image)

# %%
imageio.imsave('test_clean.tiff', actual_image)

# %%
raw.color_desc
# Out:
# b'RGBG'

# %%
raw.color_matrix
# Out:
# array([[ 1.8523828 ,  0.26705515, -1.1194379 ,  0.        ],
#        [-0.32426944,  1.6637666 , -0.33949718,  0.        ],
#        [ 0.01523797, -0.37744585,  1.3622079 ,  0.        ]],
#       dtype=float32)

# %%
raw.daylight_whitebalance
# Out:
# [1.0195244550704956, 0.8540831208229065, 1.3546675443649292, 0.0]

# %%
raw.num_colors
# Out:
# 3

# %% [markdown]
# I think this is the Bayer pattern, with the colors given in raw.color_desc

# %%
raw.raw_pattern
# Out:
# array([[0, 1],
#        [3, 2]], dtype=uint8)

# %%
raw.color_desc
# Out:
# b'RGBG'

# %%
np.std(actual_image)
# Out:
# 0.3644447440012462

# %%
np.std(raw.raw_image)
# Out:
# 0.3644447440012462

# %%
np.mean(raw.raw_image)
# Out:
# 1022.9368768294514

# %%
raw.close()

# %%
data = pd.DataFrame()

for fn in fn_list:
    with exiftool.ExifToolHelper() as et:
        metadata = et.get_metadata(fn)[0]
    raw = rawpy.imread(fn)
    
    #handle black level as string of levels per channel - happens in Leica Q
    black_level = metadata.get('EXIF:BlackLevel')
    if isinstance(black_level, str):
        black_level = int(black_level.split()[0])
        
    df = pd.DataFrame({
        'camera':[metadata.get('EXIF:UniqueCameraModel')],
        'source':[metadata.get('SourceFile')],
        'black_level':[black_level],
        'white_level':[metadata.get('EXIF:WhiteLevel')],
        'width':[metadata.get('EXIF:ExifImageWidth')],
        'height':[metadata.get('EXIF:ExifImageHeight')],
        #'white':[raw.white_level],
        'iso':[metadata.get('EXIF:ISO')],
        'time':[metadata.get('EXIF:ExposureTime')],
        'std':[np.std(raw.raw_image)],
        'mean':[np.mean(raw.raw_image)],
        'min':[np.min(raw.raw_image)],
        'max':[np.max(raw.raw_image)],
    })
    data = pd.concat([data, df])
    raw.close()
#exposure value - (max digital range)/(std dev)
data['EV'] = data.apply(lambda x: np.log((x['white_level']-x['black_level'])/x['std'])/np.log(2), axis='columns')

# %%
px.line(data, x='iso', y='EV', markers=True, log_x=True)

# %%
fn_list
# Out:
# ['L1000155.DNG',
#  'L1000156.DNG',
#  'L1000157.DNG',
#  'L1000158.DNG',
#  'L1000159.DNG',
#  'L1000160.DNG',
#  'L1000161.DNG',
#  'L1000162.DNG',
#  'L1000163.DNG',
#  'L1000164.DNG',
#  'L1000165.DNG']

# %%
fn
# Out:
# 'L1000165.DNG'

# %%
path = "/home/steven/leica/iso32000"
data = pd.DataFrame()

fn_list = sorted([i for i in os.listdir(path) if i.endswith(suffix)])

for fn_base in fn_list:
    fn = os.path.join(path, fn_base)
    with exiftool.ExifToolHelper() as et:
        metadata = et.get_metadata(fn)[0]
    raw = rawpy.imread(fn)
    
    df = pd.DataFrame({
        'source':[metadata.get('SourceFile')],
        'iso':[metadata.get('EXIF:ISO')],
        'time':[metadata.get('EXIF:ExposureTime')],
        'std':[np.std(raw.raw_image)],
        'mean':[np.mean(raw.raw_image)],
        'white':[raw.white_level],
    })
    data = pd.concat([data, df])
    raw.close()

# %%
data
# Out:
#                                      source    iso      time         std  \
# 0  /home/steven/leica/iso32000/L1000226.DNG  32000  0.000250  109.803736
# 0  /home/steven/leica/iso32000/L1000227.DNG  32000  0.000500  109.825697
# 0  /home/steven/leica/iso32000/L1000228.DNG  32000  0.001000  109.812953
# 0  /home/steven/leica/iso32000/L1000229.DNG  32000  0.002000  109.863261
# 0  /home/steven/leica/iso32000/L1000230.DNG  32000  0.004000  109.877819
# 0  /home/steven/leica/iso32000/L1000231.DNG  32000  0.008000  109.975503
# 0  /home/steven/leica/iso32000/L1000232.DNG  32000  0.016667  109.960849
# 0  /home/steven/leica/iso32000/L1000233.DNG  32000  0.033333  110.111332
# 0  /home/steven/leica/iso32000/L1000234.DNG  32000  0.066667  110.436634
# 0  /home/steven/leica/iso32000/L1000235.DNG  32000  0.125000  111.019640
# 0  /home/steven/leica/iso32000/L1000236.DNG  32000  0.250000  112.024360
# 0  /home/steven/leica/iso32000/L1000237.DNG  32000  0.500000  114.073273
# 0  /home/steven/leica/iso32000/L1000238.DNG  32000  1.000000  123.110140
#
#           mean  white
# 0  2045.607274  16383
# 0  2045.659666  16383
# 0  2045.709059  16383
# 0  2045.812411  16383
# 0  2045.801118  16383
# 0  2045.908983  16383
# 0  2045.993068  16383
# 0  2046.505823  16383
# 0  2047.192917  16383
# 0  2048.444274  16383
# 0  2051.177223  16383
# 0  2056.545739  16383
# 0  2068.496631  16383

# %%
px.line(data, x='time', y='mean', markers=True)

# %%
px.line(data, x='time', y='std', markers=True)

# %% [markdown]
# ## Checking SL2-S mid-ISO

# %%
metadata_400 = [i for i in metadata if i.get('EXIF:ISO') == 400]

# %%
metadata_400[0].get('SourceFile')
# Out:
# 'SL2-S-24MP/L1000647.DNG'

# %%
image = rawpy.imread(metadata_400[0].get('SourceFile')).raw_image

# %%
imageio.imsave('test.tiff', image)

# %% [markdown]
# ## Noise on 50% white image on Leica CL

# %%
os.getcwd()
# Out:
# '/home/steven/leica'

# %%
fn = "/home/steven/leica/CL-24MP-PHOTON/L1040859.DNG"
#fn = "/home/steven/leica/CL-24MP/L1030845.DNG"
with exiftool.ExifToolHelper() as et:
    metadata = et.get_metadata([fn])
metadata
# Out:
# [{'SourceFile': '/home/steven/leica/CL-24MP-PHOTON/L1040859.DNG',
#   'ExifTool:ExifToolVersion': 12.4,
#   'File:FileName': 'L1040859.DNG',
#   'File:Directory': '/home/steven/leica/CL-24MP-PHOTON',
#   'File:FileSize': 43585536,
#   'File:FileModifyDate': '2023:07:29 07:04:54-06:00',
#   'File:FileAccessDate': '2023:07:29 13:05:10-06:00',
#   'File:FileInodeChangeDate': '2023:07:29 13:05:10-06:00',
#   'File:FilePermissions': 100755,
#   'File:FileType': 'DNG',
#   'File:FileTypeExtension': 'DNG',
#   'File:MIMEType': 'image/x-adobe-dng',
#   'File:ExifByteOrder': 'II',
#   'EXIF:Make': 'LEICA CAMERA AG',
#   'EXIF:Model': 'LEICA CL',
#   'EXIF:Orientation': 1,
#   'EXIF:Software': 4.1,
#   'EXIF:ModifyDate': '2023:07:29 13:04:54',
#   'EXIF:Artist': '',
#   'EXIF:ImageWidth': 6120,
#   'EXIF:ImageHeight': 4016,
#   'EXIF:BitsPerSample': 14,
#   'EXIF:Compression': 1,
#   'EXIF:PhotometricInterpretation': 32803,
#   'EXIF:StripOffsets': 573952,
#   'EXIF:SamplesPerPixel': 1,
#   'EXIF:RowsPerStrip': 4016,
#   'EXIF:StripByteCounts': 43011584,
#   'EXIF:XResolution': 300,
#   'EXIF:YResolution': 300,
#   'EXIF:ResolutionUnit': 2,
#   'EXIF:CFARepeatPatternDim': '2 2',
#   'EXIF:CFAPattern2': '1 2 0 1',
#   'EXIF:CFALayout': 1,
#   'EXIF:BlackLevelRepeatDim': '2 2',
#   'EXIF:BlackLevel': '511 511 511 511',
#   'EXIF:WhiteLevel': 16383,
#   'EXIF:DefaultCropOrigin': '8 8',
#   'EXIF:DefaultCropSize': '6000 4000',
#   'EXIF:BayerGreenSplit': 0,
#   'EXIF:AntiAliasStrength': 0.7,
#   'EXIF:BestQualityScale': 1,
#   'EXIF:RawDataUniqueID': '5B0336040D1D07E707C9535100000000',
#   'EXIF:ActiveArea': '0 0 4016 6016',
#   'EXIF:OpcodeList1': '(Binary data 28 bytes, use -b option to extract)',
#   'EXIF:OpcodeList3': '(Binary data 184 bytes, use -b option to extract)',
#   'EXIF:DefaultUserCrop': '0 0 1 1',
#   'EXIF:PreviewImageStart': 536064,
#   'EXIF:PreviewImageLength': 37888,
#   'EXIF:SubfileType': 1,
#   'EXIF:JpgFromRawStart': 44544,
#   'EXIF:JpgFromRawLength': 491520,
#   'EXIF:Copyright': '',
#   'EXIF:ExposureTime': 0.004,
#   'EXIF:FNumber': 0,
#   'EXIF:ExposureProgram': 1,
#   'EXIF:ISO': 100,
#   'EXIF:SensitivityType': 1,
#   'EXIF:StandardOutputSensitivity': 100,
#   'EXIF:ExifVersion': '0230',
#   'EXIF:DateTimeOriginal': '2023:07:29 13:04:54',
#   'EXIF:CreateDate': '2023:07:29 13:04:54',
#   'EXIF:ComponentsConfiguration': '1 2 3 0',
#   'EXIF:ExposureCompensation': 0,
#   'EXIF:MaxApertureValue': 3.79428520271266,
#   'EXIF:MeteringMode': 5,
#   'EXIF:LightSource': 0,
#   'EXIF:Flash': 16,
#   'EXIF:FocalLength': 0,
#   'EXIF:FlashpixVersion': '0100',
#   'EXIF:ColorSpace': 1,
#   'EXIF:ExifImageWidth': 6120,
#   'EXIF:ExifImageHeight': 4016,
#   'EXIF:SensingMethod': 2,
#   'EXIF:FileSource': 3,
#   'EXIF:CustomRendered': 0,
#   'EXIF:WhiteBalance': 0,
#   'EXIF:DigitalZoomRatio': 1,
#   'EXIF:FocalLengthIn35mmFormat': 0,
#   'EXIF:SceneCaptureType': 0,
#   'EXIF:Contrast': 0,
#   'EXIF:Saturation': 0,
#   'EXIF:Sharpness': 0,
#   'EXIF:LensInfo': 'undef undef 3.84765625 3.84765625',
#   'EXIF:LensMake': 'N/A',
#   'EXIF:LensModel': 'N/A',
#   'EXIF:LensSerialNumber': 'N/A',
#   'EXIF:DNGVersion': '1 4 0 0',
#   'EXIF:DNGBackwardVersion': '1 3 0 0',
#   'EXIF:UniqueCameraModel': 'LEICA CL',
#   'EXIF:LocalizedCameraModel': 'LEICA CL',
#   'EXIF:ColorMatrix1': '0.976 -0.385 0.012 -0.523 1.454 0.348 -0.095 0.186 0.723',
#   'EXIF:ColorMatrix2': '0.697 -0.225 -0.079 -0.482 1.239 0.201 -0.149 0.232 0.476',
#   'EXIF:AsShotNeutral': '0.3965917893 1 0.6084373143',
#   'EXIF:BaselineNoise': 1,
#   'EXIF:BaselineSharpness': 1,
#   'EXIF:LinearResponseLimit': 1,
#   'EXIF:CameraSerialNumber': 5329865,
#   'EXIF:MakerNoteSafety': 0,
#   'EXIF:CalibrationIlluminant1': 17,
#   'EXIF:CalibrationIlluminant2': 21,
#   'EXIF:JpgFromRaw': '(Binary data 491520 bytes, use -b option to extract)',
#   'EXIF:PreviewImage': '(Binary data 37888 bytes, use -b option to extract)',
#   'XMP:About': 'Leica Camera AG',
#   'XMP:Rating': 0,
#   'MakerNotes:SerialNumber': 5329865,
#   'MakerNotes:OriginalFileName': 'L1040859.DNG',
#   'MakerNotes:OriginalDirectory': '104LEICA',
#   'MakerNotes:FocusDistance': 0,
#   'MakerNotes:FileIndex': 859,
#   'MakerNotes:FilmMode': '                    ',
#   'MakerNotes:WB_RGBLevels': '0.3965917893 1 0.6084373143',
#   'MakerNotes:InternalSerialNumber': 'XEL1803080093',
#   'Composite:BlueBalance': 0.6084373143,
#   'Composite:CFAPattern': '2 2 1 2 0 1',
#   'Composite:ImageSize': '6120 4016',
#   'Composite:Megapixels': 24.57792,
#   'Composite:RedBalance': 0.3965917893,
#   'Composite:ShutterSpeed': 0.004,
#   'Composite:FocalLength35efl': 0}]

# %%
raw = rawpy.imread(fn)

image = raw.raw_image
image = image[:, 0:6048]
image
# Out:
# array([[1658, 1251, 1653, ..., 1605, 2196, 1628],
#        [ 933, 1619,  967, ..., 2220, 1165, 2192],
#        [1593, 1219, 1621, ..., 1625, 2233, 1621],
#        ...,
#        [ 955, 1652,  924, ..., 2145, 1178, 2135],
#        [1671, 1232, 1616, ..., 1557, 2200, 1548],
#        [ 927, 1627,  924, ..., 2128, 1148, 2199]], dtype=uint16)

# %% [markdown]
# The dark mean was 511.5m

# %%
image.mean() - 511.5
# Out:
# 1492.2997148311515

# %%
The dark stddev was 1.5

# %%
image.std() - 1.5
# Out:
# 542.2570565242263

# %% [markdown]
# So for an actual image, the SNR is only

# %%
1492/542
# Out:
# 2.7527675276752768

# %%
image.min()
# Out:
# 1

# %%
image.max()
# Out:
# 16383

# %% [markdown]
# Doesn't make sense - the value should be around 50%, but it's much too low.

# %% [markdown]
# Take 2 evenly illuminated images at ISO 100 and subtract

# %%
raw1 = rawpy.imread("/home/steven/leica/CL-24MP-PHOTON/L1040860.DNG")
raw2 = rawpy.imread("/home/steven/leica/CL-24MP-PHOTON/L1040861.DNG")
image1 = raw1.raw_image[:, 0:6048]/16383
image2 = raw2.raw_image[:, 0:6048]/16383

# %%
image2
# Out:
# array([[0.09766221, 0.07532198, 0.10089727, ..., 0.10065312, 0.13404138,
#         0.09595312],
#        [0.05658304, 0.10101935, 0.05658304, ..., 0.13141671, 0.07049991,
#         0.13239333],
#        [0.09924922, 0.07422328, 0.09790637, ..., 0.09876091, 0.13575047,
#         0.09888299],
#        ...,
#        [0.05621681, 0.09790637, 0.05566746, ..., 0.13349203, 0.06854666,
#         0.12995178],
#        [0.09918818, 0.07648172, 0.09851676, ..., 0.09375572, 0.13166087,
#         0.09656351],
#        [0.05670512, 0.09680767, 0.05554538, ..., 0.12879204, 0.06952329,
#         0.13147775]])

# %%
image_diff = (image1 - image2)

# %%
image_diff.mean()*16383
# Out:
# -2.364144653199355

# %%
image_diff.std()*16383
# Out:
# 32.998245941552746

# %% [markdown]
# This is the actual photo noise, actually divide by sqrt(2) because it's 2 images. The pattern noise is removed.

# %%
33/2**0.5
# Out:
# 23.33452377915607

# %% [markdown]
# The dark level noramlized to 1 is

# %%
511/16383
# Out:
# 0.031190868583287554

# %% [markdown]
# Using this offset, we get an actual mean of

# %%
image1.mean()*16383 - 511
# Out:
# 1435.3575191215948

# %%
image2.mean()*16383 - 511
# Out:
# 1437.7216637747952

# %%
np.log(1437/16383)
# Out:
# -2.4336866047412387

# %% [markdown]
# I suspect the x-axis of the histogram is a log scale, and I positioned it around the 50% point.

# %% [markdown]
# ### Number of photos

# %% [markdown]
# The SNR is

# %%
1437/23.3
# Out:
# 61.67381974248927

# %% [markdown]
# The SNR for $n$ photos is $\sqrt{n}$, so $n = 61.67^{2}$

# %%
61.7**2
# Out:
# 3806.8900000000003

# %% [markdown]
# At around ISO 6400 the detector noise becomes higher than 23. Oh, but the photon noise should scale with the gain.
#
# I'm confused. The photon noise seems much too large.

# %% [markdown]
# ## Noise on 180% grey (mid histogram) on Leica CL

# %%
os.getcwd()
# Out:
# '/home/steven/leica'

# %%
fn1 = "/home/steven/leica/CL-24MP-PHOTON/ISO100_18GREY_A.DNG"
fn2 = "/home/steven/leica/CL-24MP-PHOTON/ISO100_18GREY_B.DNG"
#fn = "/home/steven/leica/CL-24MP/L1030845.DNG"
with exiftool.ExifToolHelper() as et:
    metadata = et.get_metadata([fn])
metadata
# Out:
# [{'SourceFile': '/home/steven/leica/CL-24MP-PHOTON/ISO100_18GREY_A.DNG',
#   'ExifTool:ExifToolVersion': 12.4,
#   'File:FileName': 'ISO100_18GREY_A.DNG',
#   'File:Directory': '/home/steven/leica/CL-24MP-PHOTON',
#   'File:FileSize': 43581952,
#   'File:FileModifyDate': '2023:07:30 08:52:28-06:00',
#   'File:FileAccessDate': '2023:07:30 14:57:14-06:00',
#   'File:FileInodeChangeDate': '2023:07:30 14:54:11-06:00',
#   'File:FilePermissions': 100755,
#   'File:FileType': 'DNG',
#   'File:FileTypeExtension': 'DNG',
#   'File:MIMEType': 'image/x-adobe-dng',
#   'File:ExifByteOrder': 'II',
#   'EXIF:Make': 'LEICA CAMERA AG',
#   'EXIF:Model': 'LEICA CL',
#   'EXIF:Orientation': 1,
#   'EXIF:Software': 4.1,
#   'EXIF:ModifyDate': '2023:07:30 14:52:28',
#   'EXIF:Artist': '',
#   'EXIF:ImageWidth': 6120,
#   'EXIF:ImageHeight': 4016,
#   'EXIF:BitsPerSample': 14,
#   'EXIF:Compression': 1,
#   'EXIF:PhotometricInterpretation': 32803,
#   'EXIF:StripOffsets': 570368,
#   'EXIF:SamplesPerPixel': 1,
#   'EXIF:RowsPerStrip': 4016,
#   'EXIF:StripByteCounts': 43011584,
#   'EXIF:XResolution': 300,
#   'EXIF:YResolution': 300,
#   'EXIF:ResolutionUnit': 2,
#   'EXIF:CFARepeatPatternDim': '2 2',
#   'EXIF:CFAPattern2': '1 2 0 1',
#   'EXIF:CFALayout': 1,
#   'EXIF:BlackLevelRepeatDim': '2 2',
#   'EXIF:BlackLevel': '510 511 511 511',
#   'EXIF:WhiteLevel': 16383,
#   'EXIF:DefaultCropOrigin': '8 8',
#   'EXIF:DefaultCropSize': '6000 4000',
#   'EXIF:BayerGreenSplit': 0,
#   'EXIF:AntiAliasStrength': 0.7,
#   'EXIF:BestQualityScale': 1,
#   'EXIF:RawDataUniqueID': '0B001C340E1E07E707C9535100000000',
#   'EXIF:ActiveArea': '0 0 4016 6016',
#   'EXIF:OpcodeList1': '(Binary data 28 bytes, use -b option to extract)',
#   'EXIF:OpcodeList3': '(Binary data 184 bytes, use -b option to extract)',
#   'EXIF:DefaultUserCrop': '0 0 1 1',
#   'EXIF:PreviewImageStart': 532992,
#   'EXIF:PreviewImageLength': 37376,
#   'EXIF:SubfileType': 1,
#   'EXIF:JpgFromRawStart': 44544,
#   'EXIF:JpgFromRawLength': 488448,
#   'EXIF:Copyright': '',
#   'EXIF:ExposureTime': 0.0008,
#   'EXIF:FNumber': 0,
#   'EXIF:ExposureProgram': 4,
#   'EXIF:ISO': 100,
#   'EXIF:SensitivityType': 1,
#   'EXIF:StandardOutputSensitivity': 100,
#   'EXIF:ExifVersion': '0230',
#   'EXIF:DateTimeOriginal': '2023:07:30 14:52:28',
#   'EXIF:CreateDate': '2023:07:30 14:52:28',
#   'EXIF:ComponentsConfiguration': '1 2 3 0',
#   'EXIF:ExposureCompensation': 0,
#   'EXIF:MaxApertureValue': 3.79428520271266,
#   'EXIF:MeteringMode': 5,
#   'EXIF:LightSource': 0,
#   'EXIF:Flash': 16,
#   'EXIF:FocalLength': 0,
#   'EXIF:FlashpixVersion': '0100',
#   'EXIF:ColorSpace': 1,
#   'EXIF:ExifImageWidth': 6120,
#   'EXIF:ExifImageHeight': 4016,
#   'EXIF:SensingMethod': 2,
#   'EXIF:FileSource': 3,
#   'EXIF:CustomRendered': 0,
#   'EXIF:WhiteBalance': 0,
#   'EXIF:DigitalZoomRatio': 1,
#   'EXIF:FocalLengthIn35mmFormat': 0,
#   'EXIF:SceneCaptureType': 0,
#   'EXIF:Contrast': 0,
#   'EXIF:Saturation': 0,
#   'EXIF:Sharpness': 0,
#   'EXIF:LensInfo': 'undef undef 3.84765625 3.84765625',
#   'EXIF:LensMake': 'N/A',
#   'EXIF:LensModel': 'N/A',
#   'EXIF:LensSerialNumber': 'N/A',
#   'EXIF:DNGVersion': '1 4 0 0',
#   'EXIF:DNGBackwardVersion': '1 3 0 0',
#   'EXIF:UniqueCameraModel': 'LEICA CL',
#   'EXIF:LocalizedCameraModel': 'LEICA CL',
#   'EXIF:ColorMatrix1': '0.976 -0.385 0.012 -0.523 1.454 0.348 -0.095 0.186 0.723',
#   'EXIF:ColorMatrix2': '0.697 -0.225 -0.079 -0.482 1.239 0.201 -0.149 0.232 0.476',
#   'EXIF:AsShotNeutral': '0.385978138 1 0.571747627',
#   'EXIF:BaselineNoise': 1,
#   'EXIF:BaselineSharpness': 1,
#   'EXIF:LinearResponseLimit': 1,
#   'EXIF:CameraSerialNumber': 5329865,
#   'EXIF:MakerNoteSafety': 0,
#   'EXIF:CalibrationIlluminant1': 17,
#   'EXIF:CalibrationIlluminant2': 21,
#   'EXIF:JpgFromRaw': '(Binary data 488448 bytes, use -b option to extract)',
#   'EXIF:PreviewImage': '(Binary data 37376 bytes, use -b option to extract)',
#   'XMP:About': 'Leica Camera AG',
#   'XMP:Rating': 0,
#   'MakerNotes:SerialNumber': 5329865,
#   'MakerNotes:OriginalFileName': 'L1050011.DNG',
#   'MakerNotes:OriginalDirectory': '105LEICA',
#   'MakerNotes:FocusDistance': 0,
#   'MakerNotes:FileIndex': 11,
#   'MakerNotes:FilmMode': '                    ',
#   'MakerNotes:WB_RGBLevels': '0.385978138 1 0.571747627',
#   'MakerNotes:InternalSerialNumber': 'XEL1803080093',
#   'Composite:BlueBalance': 0.571747627,
#   'Composite:CFAPattern': '2 2 1 2 0 1',
#   'Composite:ImageSize': '6120 4016',
#   'Composite:Megapixels': 24.57792,
#   'Composite:RedBalance': 0.385978138,
#   'Composite:ShutterSpeed': 0.0008,
#   'Composite:FocalLength35efl': 0}]

# %%
white_level = metadata[0].get('EXIF:WhiteLevel')

# %%
black_level = int(metadata[0].get('EXIF:BlackLevel').split(' ')[0])

# %%
levels = white_level - black_level

# %%
raw_a = rawpy.imread(fn1)
raw_b = rawpy.imread(fn2)

image1 = raw1.raw_image/levels
image1 = image1[:, 0:6048]
image2 = raw2.raw_image/levels
image2 = image2[:, 0:6048]
image1
# Out:
# array([[0.1041391 , 0.07793108, 0.1014301 , ..., 0.1008631 , 0.13652114,
#         0.1008631 ],
#        [0.05777106, 0.1049581 , 0.05865306, ..., 0.13986014, 0.07326907,
#         0.13708814],
#        [0.1024381 , 0.07597808, 0.1019341 , ..., 0.1013671 , 0.13746614,
#         0.1005481 ],
#        ...,
#        [0.05789706, 0.0996031 , 0.05840106, ..., 0.13406413, 0.07402507,
#         0.13532414],
#        [0.1036351 , 0.07799408, 0.1000441 , ..., 0.0986581 , 0.13500914,
#         0.0976501 ],
#        [0.05682606, 0.0999181 , 0.05745606, ..., 0.13727714, 0.07169407,
#         0.13437913]])

# %%
delta = image1 - image2

# %%
delta.std()/2**0.5
# Out:
# 0.0014699983287679384

# %%
delta.mean()
# Out:
# -0.00014894126209282215

# %%
image1.mean()
# Out:
# 0.12262064632530696

# %%
image2.mean()
# Out:
# 0.12276958758739953

# %%
snr = image1.mean()/(delta.std()/2**0.5)
snr
# Out:
# 83.41550049793594

# %%
photons = snr**2
photons
# Out:
# 6958.14572332115

# %% [markdown]
# Got about 3800 using the noisy image. I should manually examine an image to make sure there isn't pattern noise - but subtracting shoudl take care of that.

# %% [markdown]
# lux = lumen/s/m**2.

# %% [markdown]
# ## Sanity check - fully saturated detectotr

# %% [markdown]
# Let's see what a totally saturated detector looks like.

# %%
raw1 = rawpy.imread("/home/steven/leica/CL-24MP-PHOTON/L1040864.DNG")
raw2 = rawpy.imread("/home/steven/leica/CL-24MP-PHOTON/L1040865.DNG")
sat1 = raw1.raw_image[:, 0:6048]/16383
sat2 = raw2.raw_image[:, 0:6048]/16383

# %%
sat1
# Out:
# array([[0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        ...,
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896]])

# %%
sat2
# Out:
# array([[0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        ...,
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896],
#        [0.99993896, 0.99993896, 0.99993896, ..., 0.99993896, 0.99993896,
#         0.99993896]])

# %%
image_diff = image1-image2

# %%
image_diff.mean()
# Out:
# 0.0

# %%
image_diff.std()
# Out:
# 0.0
